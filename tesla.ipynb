# %%
# %pip install sec-api

from sec_api import QueryApi

queryApi = QueryApi(api_key="7f476c4242c26ec099952c19c5580602b556600e00169d3e96404ce37101b892")  


query = {
  "query": {
    "query_string": {
      "query": "ticker:TSLA AND formType:\"10-Q\""
    }
  },
  "from": "0",
  "size": "5",
  "sort": [{ "filedAt": { "order": "desc" } }]
}

response = queryApi.get_filings(query)
print(response)
# Out:
# Requirement already satisfied: sec-api in c:\users\madio\anaconda3\lib\site-packages (1.0.32)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\madio\anaconda3\lib\site-packages (from sec-api) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\madio\anaconda3\lib\site-packages (from requests->sec-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\madio\anaconda3\lib\site-packages (from requests->sec-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\madio\anaconda3\lib\site-packages (from requests->sec-api) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\madio\anaconda3\lib\site-packages (from requests->sec-api) (2024.8.30)
# {'total': {'value': 45, 'relation': 'eq'}, 'query': {'from': 0, 'size': 5}, 'filings': [{'ticker': 'TSLA', 'formType': '10-Q', 'accessionNo': '0001628280-25-018911', 'cik': '1318605', 'companyNameLong': 'Tesla, Inc. (Filer)', 'companyName': 'Tesla, Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331.htm', 'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/0001628280-25-018911.txt', 'filedAt': '2025-04-22T21:02:10-04:00', 'documentFormatFiles': [{'sequence': '1', 'size': '1225850', 'documentUrl': 'https://www.sec.gov/ix?doc=/Archives/edgar/data/1318605/000162828025018911/tsla-20250331.htm', 'description': '10-Q', 'type': '10-Q'}, {'sequence': '2', 'size': '10236', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-2025x03x31xex311.htm', 'description': 'EX-31.1', 'type': 'EX-31.1'}, {'sequence': '3', 'size': '10215', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-2025x03x31xex312.htm', 'description': 'EX-31.2', 'type': 'EX-31.2'}, {'sequence': '4', 'size': '6463', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-2025x03x31xex321.htm', 'description': 'EX-32.1', 'type': 'EX-32.1'}, {'sequence': '\xa0', 'size': '7508813', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/0001628280-25-018911.txt', 'description': 'Complete submission text file', 'type': '\xa0'}], 'periodOfReport': '2025-03-31', 'entities': [{'fiscalYearEnd': '1231', 'stateOfIncorporation': 'DE', 'act': '34', 'cik': '1318605', 'fileNo': '001-34756', 'companyName': 'Tesla, Inc. (Filer)', 'type': '10-Q', 'sic': '3711 Motor Vehicles &amp; Passenger Car Bodies', 'filmNo': '25859036', 'undefined': '04 Manufacturing)'}], 'id': '2abab8a670ff266d6d9458f6e936f4ba', 'seriesAndClassesContractsInformation': [], 'linkToHtml': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/0001628280-25-018911-index.htm', 'linkToXbrl': '', 'dataFiles': [{'sequence': '5', 'size': '51488', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331.xsd', 'description': 'XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT', 'type': 'EX-101.SCH'}, {'sequence': '6', 'size': '80074', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331_cal.xml', 'description': 'XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT', 'type': 'EX-101.CAL'}, {'sequence': '7', 'size': '238385', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331_def.xml', 'description': 'XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT', 'type': 'EX-101.DEF'}, {'sequence': '8', 'size': '600968', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331_lab.xml', 'description': 'XBRL TAXONOMY EXTENSION LABEL LINKBASE DOCUMENT', 'type': 'EX-101.LAB'}, {'sequence': '9', 'size': '418897', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331_pre.xml', 'description': 'XBRL TAXONOMY EXTENSION PRESENTATION LINKBASE DOCUMENT', 'type': 'EX-101.PRE'}, {'sequence': '81', 'size': '1217454', 'documentUrl': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828025018911/tsla-20250331_htm.xml', 'description': 'EXTRACTED XBRL INSTANCE DOCUMENT', 'type': 'XML'}]}, {'ticker': 'TSLA', 'formType': '10-Q', 'accessionNo': '0001628280-24-043486', 'cik': '1318605', 'companyNameLong': 'Tesla, Inc. (Filer)', 'companyName': 'Tesla, Inc.', 'linkToFilingDetails': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828024043486/tsla-20240930.htm', 'description': 'Form 10-Q - Quarterly report [Sections 13 or 15(d)]', 'linkToTxt': 'https://www.sec.gov/Archives/edgar/data/1318605/000162828024043486/0001628280-24-043486.txt', 'filedAt': '2024-10- ...
